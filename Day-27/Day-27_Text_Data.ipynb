# %% [markdown]
# #### Bài tập:
# Hãy thực hiện các task: POS Tagging, Text Classification, Sentiment Analysis, Sentence Segmentation, Word Segmentation cho đoạn văn sau:
# *Công cụ Suno AI nhanh chóng nhận được sự chú ý từ người dùng khi có thể tạo bài hát chỉ với vài câu lệnh. Phiên bản mới nhất V3 Alpha mới được giới thiệu cuối tháng 2, có bản miễn phí với 10 bài hát mỗi ngày.*

# %%
#!pip install underthesea

# %%
from underthesea import pos_tag, classify, sentiment, sent_tokenize, word_tokenize

# %%
sentence = "Công cụ Suno AI nhanh chóng nhận được sự chú ý từ người dùng khi có thể tạo bài hát chỉ với vài câu lệnh. Phiên bản mới nhất V3 Alpha mới được giới thiệu cuối tháng 2, có bản miễn phí với 10 bài hát mỗi ngày."

# %%
pos_tag(sentence)
# Out:
# [('Công cụ', 'N'),
#  ('Suno', 'Np'),
#  ('AI', 'P'),
#  ('nhanh chóng', 'A'),
#  ('nhận', 'V'),
#  ('được', 'R'),
#  ('sự', 'N'),
#  ('chú ý', 'V'),
#  ('từ', 'E'),
#  ('người', 'N'),
#  ('dùng', 'V'),
#  ('khi', 'N'),
#  ('có thể', 'R'),
#  ('tạo', 'V'),
#  ('bài', 'N'),
#  ('hát', 'V'),
#  ('chỉ', 'R'),
#  ('với', 'E'),
#  ('vài', 'L'),
#  ('câu', 'N'),
#  ('lệnh', 'N'),
#  ('.', 'CH'),
#  ('Phiên bản', 'V'),
#  ('mới', 'A'),
#  ('nhất', 'A'),
#  ('V3 Alpha', 'Np'),
#  ('mới', 'R'),
#  ('được', 'V'),
#  ('giới thiệu', 'V'),
#  ('cuối', 'N'),
#  ('tháng', 'N'),
#  ('2', 'M'),
#  (',', 'CH'),
#  ('có', 'V'),
#  ('bản', 'N'),
#  ('miễn phí', 'V'),
#  ('với', 'E'),
#  ('10', 'M'),
#  ('bài', 'N'),
#  ('hát', 'V'),
#  ('mỗi', 'L'),
#  ('ngày', 'N'),
#  ('.', 'CH')]

# %%
classify(sentence)
# Out:
# 2024-04-16 22:43:53,873 https://github.com/undertheseanlp/playground/releases/download/1.3.x/tc_svm_vntc_20201228.zip not found in cache, downloading to /var/folders/ny/3552wwqn5j1g39230x5tx8m00000gn/T/tmp7m3k_lrh
# 100%|██████████| 75578053/75578053 [00:18<00:00, 4057270.38B/s]
# 2024-04-16 22:44:14,815 copying /var/folders/ny/3552wwqn5j1g39230x5tx8m00000gn/T/tmp7m3k_lrh to cache at /Users/chaupham/.underthesea/models/tc_svm_vntc_20201228.zip
# 2024-04-16 22:44:14,851 removing temp file /var/folders/ny/3552wwqn5j1g39230x5tx8m00000gn/T/tmp7m3k_lrh
# ['vi_tinh']

# %%
sentiment(sentence)
# Out:
# 2024-04-16 22:44:22,084 https://github.com/undertheseanlp/playground/releases/download/1.3.x/sa_svm_vlsp2016-sa_20210107.zip not found in cache, downloading to /var/folders/ny/3552wwqn5j1g39230x5tx8m00000gn/T/tmp62i4are4
# 100%|██████████| 2234880/2234880 [00:03<00:00, 732031.06B/s]
# 2024-04-16 22:44:26,251 copying /var/folders/ny/3552wwqn5j1g39230x5tx8m00000gn/T/tmp62i4are4 to cache at /Users/chaupham/.underthesea/models/sa_svm_vlsp2016-sa_20210107.zip
# 2024-04-16 22:44:26,256 removing temp file /var/folders/ny/3552wwqn5j1g39230x5tx8m00000gn/T/tmp62i4are4
# 'positive'

# %%
sent_tokenize(sentence)
# Out:
# ['Công cụ Suno AI nhanh chóng nhận được sự chú ý từ người dùng khi có thể tạo bài hát chỉ với vài câu lệnh.',
#  'Phiên bản mới nhất V3 Alpha mới được giới thiệu cuối tháng 2, có bản miễn phí với 10 bài hát mỗi ngày.']

# %%
word_tokenize(sentence)
# Out:
# ['Công cụ',
#  'Suno',
#  'AI',
#  'nhanh chóng',
#  'nhận',
#  'được',
#  'sự',
#  'chú ý',
#  'từ',
#  'người',
#  'dùng',
#  'khi',
#  'có thể',
#  'tạo',
#  'bài',
#  'hát',
#  'chỉ',
#  'với',
#  'vài',
#  'câu',
#  'lệnh',
#  '.',
#  'Phiên bản',
#  'mới',
#  'nhất',
#  'V3 Alpha',
#  'mới',
#  'được',
#  'giới thiệu',
#  'cuối',
#  'tháng',
#  '2',
#  ',',
#  'có',
#  'bản',
#  'miễn phí',
#  'với',
#  '10',
#  'bài',
#  'hát',
#  'mỗi',
#  'ngày',
#  '.']
